# %% [markdown]
# # ==========================================
# # PYTHON FAKER LIBRARY - COMPLETE BASIC GUIDE
# # ==========================================

# %%
pip install faker
# Out:
# Collecting faker
#   Downloading faker-40.15.0-py3-none-any.whl.metadata (16 kB)
# Downloading faker-40.15.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.1 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-40.15.0

# %%
# Import Faker
from faker import Faker

# %%
# Create Faker Object
fake = Faker()

# %% [markdown]
# # ==========================================
# # 1. BASIC USER INFORMATION
# # ==========================================

# %%
print("===== BASIC USER INFO =====")

# Random Full Name
print("Name:", fake.name())

# First Name
print("First Name:", fake.first_name())

# Last Name
print("Last Name:", fake.last_name())

# Male Name
print("Male Name:", fake.name_male())

# Female Name
print("Female Name:", fake.name_female())

# Username
print("Username:", fake.user_name())

# Password
print("Password:", fake.password())

print("\n")
# Out:
# ===== BASIC USER INFO =====
# Name: Seth Gibson
# First Name: Mary
# Last Name: Graham
# Male Name: Christopher Alvarez
# Female Name: Heather Jones
# Username: bchen
# Password: NdVE(m1K&2

# %% [markdown]
# # ==========================================
# # 2. EMAIL & INTERNET DATA
# # ==========================================

# %%
print("===== EMAIL & INTERNET =====")

# Email Address
print("Email:", fake.email())

# Company Email
print("Company Email:", fake.company_email())

# Free Email
print("Free Email:", fake.free_email())

# URL / Website
print("Website:", fake.url())

# Domain Name
print("Domain:", fake.domain_name())

# IPv4 Address
print("IPv4:", fake.ipv4())

print("\n")
# Out:
# ===== EMAIL & INTERNET =====
# Email: ucunningham@example.net
# Company Email: garrettjessica@wong-dodson.com
# Free Email: dawn27@hotmail.com
# Website: http://www.riley-vargas.com/
# Domain: jones.com
# IPv4: 62.65.157.180

# %% [markdown]
# # ==========================================
# # 3. PHONE & ADDRESS
# # ==========================================

# %%
print("===== PHONE & ADDRESS =====")

# Phone Number
print("Phone:", fake.phone_number())

# Full Address
print("Address:", fake.address())

# City
print("City:", fake.city())

# Country
print("Country:", fake.country())

# Postal Code
print("Postal Code:", fake.postcode())

# Latitude & Longitude
print("Latitude:", fake.latitude())
print("Longitude:", fake.longitude())

print("\n")
# Out:
# ===== PHONE & ADDRESS =====
# Phone: 001-708-879-1161
# Address: 1939 Dawn Port Suite 595
# Christianchester, ID 42706
# City: New Monica
# Country: Niger
# Postal Code: 07460
# Latitude: -58.8895895
# Longitude: 128.010154

# %% [markdown]
# # ==========================================
# # 4. COMPANY INFORMATION
# # ==========================================

# %%
print("===== COMPANY DATA =====")

# Company Name
print("Company:", fake.company())

# Company Slogan
print("Catch Phrase:", fake.catch_phrase())

# Business Sentence
print("BS:", fake.bs())

# Job Title
print("Job:", fake.job())

print("\n")
# Out:
# ===== COMPANY DATA =====
# Company: Mathis-Miller
# Catch Phrase: Ameliorated 3rdgeneration paradigm
# BS: mesh clicks-and-mortar content
# Job: Engineering geologist

# %% [markdown]
# # ==========================================
# # 5. DATE & TIME
# # ==========================================

# %%
print("===== DATE & TIME =====")

# Current Fake Date
print("Date:", fake.date())

# Date Time
print("Date Time:", fake.date_time())

# Year
print("Year:", fake.year())

# Month
print("Month:", fake.month())

# Time
print("Time:", fake.time())

# Future Date
print("Future Date:", fake.future_date())

print("\n")
# Out:
# ===== DATE & TIME =====
# Date: 1972-09-29
# Date Time: 1973-01-23 11:44:05.912671
# Year: 2017
# Month: 11
# Time: 02:35:34
# Future Date: 2026-06-05

# %% [markdown]
# # ==========================================
# # 6. RANDOM NUMBERS & TEXT
# # ==========================================

# %%
print("===== RANDOM DATA =====")

# Random Integer
print("Random Number:", fake.random_int(min=1, max=100))

# Random Digit
print("Random Digit:", fake.random_digit())

# Random Text
print("Text:", fake.text())

# Random Sentence
print("Sentence:", fake.sentence())

# Random Paragraph
print("Paragraph:", fake.paragraph())

print("\n")
# Out:
# ===== RANDOM DATA =====
# Random Number: 68
# Random Digit: 3
# Text: Despite walk minute box these form. That threat help ball human down step. They piece page such there area continue.
# Sentence: Control figure me ok price.
# Paragraph: Continue all also take. May order team ever. Reason weight month expect. Final necessary theory reflect story pick myself.

# %% [markdown]
# # ==========================================
# # 7. FINANCE & INVOICE DATA
# # ==========================================

# %%
print("===== FINANCE DATA =====")

# Currency Code
print("Currency:", fake.currency_code())

# Credit Card Number
print("Card Number:", fake.credit_card_number())

# Credit Card Provider
print("Card Provider:", fake.credit_card_provider())

# IBAN
print("IBAN:", fake.iban())

# Invoice UUID
print("Invoice ID:", fake.uuid4())

print("\n")
# Out:
# ===== FINANCE DATA =====
# Currency: EUR
# Card Number: 4402113908716209
# Card Provider: Maestro
# IBAN: GB51BIWM48626458780943
# Invoice ID: 36a8badf-4975-4af0-b2c9-30419372cc61

# %% [markdown]
# # ==========================================
# # 8. PROFILE DATA
# # ==========================================

# %%
print("===== PROFILE =====")

# Full Profile
profile = fake.profile()

print(profile)

print("\n")
# Out:
# ===== PROFILE =====
# {'job': 'Financial planner', 'company': 'Johnson-Keller', 'ssn': '185-93-2685', 'residence': '84672 King Junction\nPort Christina, TX 41724', 'current_location': (Decimal('16.655096'), Decimal('-174.414419')), 'blood_group': 'AB-', 'website': ['http://www.graham.org/', 'https://www.hale-henderson.com/'], 'username': 'michaeljones', 'name': 'Rachel Moss', 'sex': 'F', 'address': '9106 David Causeway Suite 238\nLake Katherine, VI 65324', 'mail': 'greencynthia@hotmail.com', 'birthdate': datetime.date(1922, 6, 21)}

# %% [markdown]
# # ==========================================
# # 9. GENERATE MULTIPLE USERS
# # ==========================================

# %%
print("===== MULTIPLE USERS =====")

for i in range(5):
    print({
        "name": fake.name(),
        "email": fake.email(),
        "phone": fake.phone_number(),
        "city": fake.city()
    })

print("\n")
# Out:
# ===== MULTIPLE USERS =====
# {'name': 'Anthony Clark', 'email': 'williamsjanet@example.net', 'phone': '653.630.7859x858', 'city': 'Port Joseshire'}
# {'name': 'Scott Tucker', 'email': 'sandovaltanner@example.com', 'phone': '(908)435-1842', 'city': 'Harrisville'}
# {'name': 'Matthew Short', 'email': 'patriciajohnson@example.net', 'phone': '4154920347', 'city': 'Batesfurt'}
# {'name': 'Casey Garcia', 'email': 'alexanderdavila@example.org', 'phone': '001-897-248-5324x90530', 'city': 'Dennischester'}
# {'name': 'Erica Huerta', 'email': 'colleen98@example.net', 'phone': '(856)809-0185x846', 'city': 'North Bethany'}

# %% [markdown]
# # ==========================================
# # 10. PAKISTANI DATA
# # ==========================================

# %%
print("===== PAKISTANI DATA =====")

# Pakistani Locale
pk_fake = Faker('en_PK')

print("Pakistani Name:", pk_fake.name())
print("Pakistani Address:", pk_fake.address())
print("Pakistani Phone:", pk_fake.phone_number())

print("\n")
# Out:
# ===== PAKISTANI DATA =====
# Pakistani Name: Qaadir Qaim
# Pakistani Address: 25705 Kachela Trafficway Apt. 772
# Rabbchester, SD 07275
# Pakistani Phone: 001-329-450-6424

# %% [markdown]
# # ==========================================
# # 11. GENERATE DUMMY DATABASE RECORDS
# # ==========================================

# %%
print("===== DUMMY USERS =====")

users = []

for i in range(3):
    user = {
        "id": i + 1,
        "name": fake.name(),
        "email": fake.email(),
        "phone": fake.phone_number(),
        "company": fake.company(),
        "address": fake.address()
    }

    users.append(user)

print(users)

print("\n")


# ==========================================
# END
# ==========================================

print("Fake Data Generation Completed Successfully!")
